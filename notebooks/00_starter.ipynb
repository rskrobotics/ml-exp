# %% [markdown]
# # ML Experiment Starter
#
# This notebook verifies your environment setup and demonstrates basic usage.

# %%
# Core imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# AutoML
from flaml import AutoML

# Causal ML
import dowhy
from dowhy import CausalModel

print("All imports successful!")

# %%
# Example: Load your data
# df = pd.read_csv('../data/raw/your_dataset.csv')
# df.head()

# %%
# Example: Quick EDA with seaborn
# sns.pairplot(df)
# plt.show()

# %%
# Example: AutoML with FLAML
# automl = AutoML()
# automl.fit(X_train, y_train, task='classification', time_budget=60)

# %%
# Example: Causal inference with DoWhy
# model = CausalModel(
#     data=df,
#     treatment='treatment_column',
#     outcome='outcome_column',
#     common_causes=['confounder1', 'confounder2']
# )
# identified_estimand = model.identify_effect()
# estimate = model.estimate_effect(identified_estimand)
